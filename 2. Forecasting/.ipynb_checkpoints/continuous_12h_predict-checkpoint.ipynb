# %%
import os
import warnings                                  # `do not disturbe` mode
warnings.filterwarnings('ignore')

import numpy as np                               # vectors and matrices
import pandas as pd                              # tables and data manipulations
import matplotlib.pyplot as plt                  # plots
                         # more plots

from dateutil.relativedelta import relativedelta # working with dates with style
from scipy.optimize import minimize              # for function minimization

import statsmodels.formula.api as smf            # statistics and econometrics
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from statsmodels.tsa.seasonal import seasonal_decompose

from itertools import product                    # some useful functions
from tqdm import tqdm_notebook

import seaborn as sns
sns.set_style(
    style='whitegrid', 
    rc={'axes.facecolor': '.95', 'grid.color': '.95'}
)

import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
tf.random.set_seed(2)

from tensorflow import keras

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Bidirectional, Flatten, GRU

from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100

os.environ['PYTHONHASHSEED'] = str(2)
np.random.seed(2)

# %%
df = pd.read_csv('output.csv')
df.head()
# Out:
#                   time  Toffice_reference  humidity  detected_motions  \
# 0  2015-01-06 15:00:00              19.45      42.0                 0
# 1  2015-01-06 15:05:00              19.45      42.0                 0
# 2  2015-01-06 15:10:00              19.45      42.0                 0
# 3  2015-01-06 15:15:00              19.45      42.0                 1
# 4  2015-01-06 15:20:00              19.45      42.0                 0
#
#    occupancy  office_CO2_concentratio     door     label
# 0        0.0               469.265967  1.00000  1.128000
# 1        0.0               448.187067  1.00000  0.622000
# 2        0.0               454.433067  1.00000  0.634000
# 3        0.0               457.387200  0.39944  0.285733
# 4        0.0               444.462833  0.00000  0.094000

# %%
df.tail()
# Out:
#                        time  Toffice_reference  humidity  detected_motions  \
# 102925  2015-12-30 00:05:00              18.35      33.0                 0
# 102926  2015-12-30 00:10:00              18.35      33.0                 0
# 102927  2015-12-30 00:15:00              18.35      33.0                 0
# 102928  2015-12-30 00:20:00              18.35      33.0                 0
# 102929  2015-12-30 00:25:00              18.35      33.0                 0
#
#         occupancy  office_CO2_concentratio  door  label
# 102925        0.0                    430.0   0.0   0.01
# 102926        0.0                    430.0   0.0   0.01
# 102927        0.0                    430.0   0.0   0.01
# 102928        0.0                    430.0   0.0   0.01
# 102929        0.0                    430.0   0.0   0.01

# %%
#Find missing data!
pd.date_range('2015-01-06 15:00:00', '2015-12-30 00:25:00', freq='5Min').difference(pd.to_datetime(df["time"]))
# Out:
# DatetimeIndex(['2015-03-29 02:00:00', '2015-03-29 02:05:00',
#                '2015-03-29 02:10:00', '2015-03-29 02:15:00',
#                '2015-03-29 02:20:00', '2015-03-29 02:25:00',
#                '2015-03-29 02:30:00', '2015-03-29 02:35:00',
#                '2015-03-29 02:40:00', '2015-03-29 02:45:00',
#                '2015-03-29 02:50:00', '2015-03-29 02:55:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
df.isna().sum()
# Out:
# time                       0
# Toffice_reference          0
# humidity                   0
# detected_motions           0
# occupancy                  0
# office_CO2_concentratio    0
# door                       0
# label                      0
# dtype: int64

# %%
df["time"]= pd.to_datetime(df["time"])
df.set_index(["time"], inplace=True)
df.head()
# Out:
#                      Toffice_reference  humidity  detected_motions  occupancy  \
# time
# 2015-01-06 15:00:00              19.45      42.0                 0        0.0
# 2015-01-06 15:05:00              19.45      42.0                 0        0.0
# 2015-01-06 15:10:00              19.45      42.0                 0        0.0
# 2015-01-06 15:15:00              19.45      42.0                 1        0.0
# 2015-01-06 15:20:00              19.45      42.0                 0        0.0
#
#                      office_CO2_concentratio     door     label
# time
# 2015-01-06 15:00:00               469.265967  1.00000  1.128000
# 2015-01-06 15:05:00               448.187067  1.00000  0.622000
# 2015-01-06 15:10:00               454.433067  1.00000  0.634000
# 2015-01-06 15:15:00               457.387200  0.39944  0.285733
# 2015-01-06 15:20:00               444.462833  0.00000  0.094000

# %%
df.drop(['Toffice_reference', 'humidity', 'detected_motions', 'occupancy', 'office_CO2_concentratio','door'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         label
# time
# 2015-01-06 15:00:00  1.128000
# 2015-01-06 15:05:00  0.622000
# 2015-01-06 15:10:00  0.634000
# 2015-01-06 15:15:00  0.285733
# 2015-01-06 15:20:00  0.094000

# %%
df[df['label']<0] = 0

# %%
df[df['label']<0]
# Out:
# Empty DataFrame
# Columns: [label]
# Index: []

# %%
data_per_5min = df
data_per_Hour = df.resample('H').sum()
data_per_5min.shape, data_per_Hour.shape
# Out:
# ((102930, 1), (8578, 1))

# %%
df.hist(bins=50)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(20, 15))
sns.boxplot(data=df, y='label')
# Out:
# <AxesSubplot:ylabel='label'>

# %%
fig, ax = plt.subplots(figsize=(32,20))

plt.subplot(2, 1, 1)
plt.plot(data_per_5min.loc['2015-02-01']['label'])
#plt.plot(data_per_5min['occupancy'])
#plt.plot(data_per_H.loc['2019-05-01':'2019-05-07',:])
plt.title('per 5 min for random days')


plt.subplot(2, 1, 2)
plt.plot(data_per_Hour['2015-02-01']['label'])
#plt.plot(data_per_D.loc['2019-05',:])
plt.title('per hour for a random days')



plt.show()
fig.tight_layout()

# %%
# fig = plt.figure(figsize=(20, 15))
# ax1 = fig.add_subplot(211)
# sns.boxplot(data=data, x='month', y='label', ax=ax1)
# ax2 = fig.add_subplot(212)
# sns.boxplot(data=data, x='weekday', y='label', ax=ax2)
# # ax3 = fig.add_subplot(313)
# # sns.boxplot(data=df, x='holiday', y='label', ax=ax3)
# plt.show()

# %%
data = data_per_Hour[:]

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(data['label'])
plot_pacf(data['label'])

# %% [markdown]
# # window 12h:

# %%
leads = np.arange(11)
lead_cols = [f"label_lead_{lead+1}" for lead in leads ]
for lead, lead_col in zip(leads, lead_cols):
    data[lead_col] = data["label"].shift(-(lead+1))

# %%
lags = np.arange(1,25)
lag_cols = [f"label_lag_{lag}" for lag in lags ]
for lag, lag_col in zip(lags, lag_cols):
    data[lag_col] = data["label"].shift(lag)

wins = [12, 24, 36, 48, 60]
for win in wins:
    for lag,lag_col in zip(lags, lag_cols):
        data[f"rmean_{lag}_{win}"] = data[lag_col].transform(lambda x : x.rolling(win).mean())
#         data[f"rmax_{lag}_{win}"] = data["label"].shift(lag).transform(lambda x : x.rolling(win).max())
#         data[f"rmin_{lag}_{win}"] = data["label"].shift(lag).transform(lambda x : x.rolling(win).min())
        data[f"rstd_{lag}_{win}"] = data[lag_col].transform(lambda x : x.rolling(win).std())

# %%
data.rename(columns={"label": "label_lead_0"}, inplace= True)

# %%
data.tail()
# Out:
#                      label_lead_0  label_lead_1  label_lead_2  label_lead_3  \
# time
# 2015-12-29 20:00:00          0.00          0.14          0.11          0.12
# 2015-12-29 21:00:00          0.14          0.11          0.12          0.06
# 2015-12-29 22:00:00          0.11          0.12          0.06           NaN
# 2015-12-29 23:00:00          0.12          0.06           NaN           NaN
# 2015-12-30 00:00:00          0.06           NaN           NaN           NaN
#
#                      label_lead_4  label_lead_5  label_lead_6  label_lead_7  \
# time
# 2015-12-29 20:00:00          0.06           NaN           NaN           NaN
# 2015-12-29 21:00:00           NaN           NaN           NaN           NaN
# 2015-12-29 22:00:00           NaN           NaN           NaN           NaN
# 2015-12-29 23:00:00           NaN           NaN           NaN           NaN
# 2015-12-30 00:00:00           NaN           NaN           NaN           NaN
#
#                      label_lead_8  label_lead_9  ...  rmean_20_60  rstd_20_60  \
# time                                             ...
# 2015-12-29 20:00:00           NaN           NaN  ...     2.376827    3.090452
# 2015-12-29 21:00:00           NaN           NaN  ...     2.268227    3.003039
# 2015-12-29 22:00:00           NaN           NaN  ...     2.187934    2.910382
# 2015-12-29 23:00:00           NaN           NaN  ...     2.089274    2.808858
# 2015-12-30 00:00:00           NaN           NaN  ...     1.990514    2.699857
#
#                      rmean_21_60  rstd_21_60  rmean_22_60  rstd_22_60  \
# time
# 2015-12-29 20:00:00     2.485427    3.171680     2.566877    3.207862
# 2015-12-29 21:00:00     2.376827    3.090452     2.485427    3.171680
# 2015-12-29 22:00:00     2.268227    3.003039     2.376827    3.090452
# 2015-12-29 23:00:00     2.187934    2.910382     2.268227    3.003039
# 2015-12-30 00:00:00     2.089274    2.808858     2.187934    2.910382
#
#                      rmean_23_60  rstd_23_60  rmean_24_60  rstd_24_60
# time
# 2015-12-29 20:00:00     2.567506    3.207641     2.590233    3.194756
# 2015-12-29 21:00:00     2.566877    3.207862     2.567506    3.207641
# 2015-12-29 22:00:00     2.485427    3.171680     2.566877    3.207862
# 2015-12-29 23:00:00     2.376827    3.090452     2.485427    3.171680
# 2015-12-30 00:00:00     2.268227    3.003039     2.376827    3.090452
#
# [5 rows x 276 columns]

# %%
data.dropna(inplace=True)

# %%
data.tail()
# Out:
#                      label_lead_0  label_lead_1  label_lead_2  label_lead_3  \
# time
# 2015-12-29 09:00:00      0.000000      0.699200      2.270400      1.292309
# 2015-12-29 10:00:00      0.699200      2.270400      1.292309      1.098200
# 2015-12-29 11:00:00      2.270400      1.292309      1.098200      1.191491
# 2015-12-29 12:00:00      1.292309      1.098200      1.191491      1.323055
# 2015-12-29 13:00:00      1.098200      1.191491      1.323055      1.476000
#
#                      label_lead_4  label_lead_5  label_lead_6  label_lead_7  \
# time
# 2015-12-29 09:00:00      1.098200      1.191491      1.323055      1.476000
# 2015-12-29 10:00:00      1.191491      1.323055      1.476000      1.500200
# 2015-12-29 11:00:00      1.323055      1.476000      1.500200      1.502444
# 2015-12-29 12:00:00      1.476000      1.500200      1.502444      0.119043
# 2015-12-29 13:00:00      1.500200      1.502444      0.119043      0.000000
#
#                      label_lead_8  label_lead_9  ...  rmean_20_60  rstd_20_60  \
# time                                             ...
# 2015-12-29 09:00:00      1.500200      1.502444  ...     2.761799    3.087255
# 2015-12-29 10:00:00      1.502444      0.119043  ...     2.737532    3.103214
# 2015-12-29 11:00:00      0.119043      0.000000  ...     2.712932    3.119193
# 2015-12-29 12:00:00      0.000000      0.140000  ...     2.688332    3.134894
# 2015-12-29 13:00:00      0.140000      0.110000  ...     2.663732    3.150322
#
#                      rmean_21_60  rstd_21_60  rmean_22_60  rstd_22_60  \
# time
# 2015-12-29 09:00:00     2.786399    3.070711     2.810999    3.053877
# 2015-12-29 10:00:00     2.761799    3.087255     2.786399    3.070711
# 2015-12-29 11:00:00     2.737532    3.103214     2.761799    3.087255
# 2015-12-29 12:00:00     2.712932    3.119193     2.737532    3.103214
# 2015-12-29 13:00:00     2.688332    3.134894     2.712932    3.119193
#
#                      rmean_23_60  rstd_23_60  rmean_24_60  rstd_24_60
# time
# 2015-12-29 09:00:00     2.832964    3.039176     2.825156    3.042098
# 2015-12-29 10:00:00     2.810999    3.053877     2.832964    3.039176
# 2015-12-29 11:00:00     2.786399    3.070711     2.810999    3.053877
# 2015-12-29 12:00:00     2.761799    3.087255     2.786399    3.070711
# 2015-12-29 13:00:00     2.737532    3.103214     2.761799    3.087255
#
# [5 rows x 276 columns]

# %%
#Scaling
scaler = MinMaxScaler()
data['label_lead_0'] = scaler.fit_transform(pd.DataFrame(data['label_lead_0']))

leads = np.arange(11)
lead_cols = [f"label_lead_{lead+1}" for lead in leads ]
for lead, lead_col in zip(leads, lead_cols):
    data[lead_col] = scaler.transform(pd.DataFrame(data[lead_col]))
   

lag_cols = [f"label_lag_{lag}" for lag in lags ]
for lag_col in lag_cols:
    data[lag_col] = scaler.transform(pd.DataFrame(data[lag_col]))

    
for win in wins:
    for lag,lag_col in zip(lags, lag_cols):
        data[f"rmean_{lag}_{win}"] = scaler.transform(pd.DataFrame(data[f"rmean_{lag}_{win}"]))
#         data[f"rmax_{lag}_{win}"] = scaler.transform(pd.DataFrame(data[f"rmax_{lag}_{win}"]))
#         data[f"rmin_{lag}_{win}"] = scaler.transform(pd.DataFrame(data[f"rmin_{lag}_{win}"]))
        data[f"rstd_{lag}_{win}"] = scaler.transform(pd.DataFrame(data[f"rstd_{lag}_{win}"]))

# %%
# make 12 step window no overlap
data = data.iloc[[i for i in range(0,len(data),12)]]
data
# Out:
#                      label_lead_0  label_lead_1  label_lead_2  label_lead_3  \
# time
# 2015-01-10 02:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-10 14:00:00      0.589809      0.440792      0.238338      0.097323
# 2015-01-11 02:00:00      0.000000      0.000000      0.001804      0.000588
# 2015-01-11 14:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-12 02:00:00      0.004974      0.015529      0.021843      0.038199
# ...                           ...           ...           ...           ...
# 2015-12-27 02:00:00      0.021474      0.023363      0.021533      0.023363
# 2015-12-27 14:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-12-28 02:00:00      0.030106      0.037408      0.061694      0.064439
# 2015-12-28 14:00:00      0.000392      0.000000      0.000000      0.000000
# 2015-12-29 02:00:00      0.062243      0.040635      0.040518      0.040518
#
#                      label_lead_4  label_lead_5  label_lead_6  label_lead_7  \
# time
# 2015-01-10 02:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-10 14:00:00      0.174303      0.141773      0.022883      0.013497
# 2015-01-11 02:00:00      0.000000      0.000000      0.000588      0.006535
# 2015-01-11 14:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-12 02:00:00      0.083686      0.075961      0.111760      0.495158
# ...                           ...           ...           ...           ...
# 2015-12-27 02:00:00      0.022906      0.025768      0.040290      0.053894
# 2015-12-27 14:00:00      0.000000      0.000355      0.000000      0.024322
# 2015-12-28 02:00:00      0.040843      0.007161      0.000000      0.000000
# 2015-12-28 14:00:00      0.000000      0.000355      0.000000      0.002204
# 2015-12-29 02:00:00      0.014259      0.000000      0.000000      0.000000
#
#                      label_lead_8  label_lead_9  ...  rmean_20_60  rstd_20_60  \
# time                                             ...
# 2015-01-10 02:00:00      0.000000      0.023604  ...     0.093176    0.162702
# 2015-01-10 14:00:00      0.003707      0.007590  ...     0.125990    0.205592
# 2015-01-11 02:00:00      0.000000      0.000000  ...     0.153598    0.222311
# 2015-01-11 14:00:00      0.000355      0.000353  ...     0.192773    0.233151
# 2015-01-12 02:00:00      0.483788      0.471921  ...     0.154499    0.227866
# ...                           ...           ...  ...          ...         ...
# 2015-12-27 02:00:00      0.011056      0.003090  ...     0.017969    0.018290
# 2015-12-27 14:00:00      0.028941      0.028941  ...     0.033392    0.049409
# 2015-12-28 02:00:00      0.038127      0.003100  ...     0.053150    0.060432
# 2015-12-28 14:00:00      0.028201      0.028941  ...     0.052353    0.061133
# 2015-12-29 02:00:00      0.013710      0.044518  ...     0.055606    0.059496
#
#                      rmean_21_60  rstd_21_60  rmean_22_60  rstd_22_60  \
# time
# 2015-01-10 02:00:00     0.103379    0.175475     0.110411    0.180131
# 2015-01-10 14:00:00     0.119746    0.202365     0.109178    0.186020
# 2015-01-11 02:00:00     0.153698    0.222242     0.153749    0.222207
# 2015-01-11 14:00:00     0.189930    0.234416     0.188867    0.234988
# 2015-01-12 02:00:00     0.158025    0.227070     0.161827    0.226298
# ...                          ...         ...          ...         ...
# 2015-12-27 02:00:00     0.017513    0.018353     0.017031    0.018428
# 2015-12-27 14:00:00     0.031140    0.046698     0.028910    0.043698
# 2015-12-28 02:00:00     0.052769    0.060698     0.052379    0.060964
# 2015-12-28 14:00:00     0.052530    0.060995     0.052530    0.060995
# 2015-12-29 02:00:00     0.054925    0.059900     0.053851    0.060303
#
#                      rmean_23_60  rstd_23_60  rmean_24_60  rstd_24_60
# time
# 2015-01-10 02:00:00     0.117591    0.184195     0.118614    0.183716
# 2015-01-10 14:00:00     0.098273    0.166618     0.090035    0.154623
# 2015-01-11 02:00:00     0.154127    0.221960     0.154176    0.221925
# 2015-01-11 14:00:00     0.184945    0.236108     0.177622    0.234849
# 2015-01-12 02:00:00     0.162574    0.225834     0.163139    0.225463
# ...                          ...         ...          ...         ...
# 2015-12-27 02:00:00     0.016548    0.018489     0.016066    0.018538
# 2015-12-27 14:00:00     0.026838    0.040355     0.024753    0.036588
# 2015-12-28 02:00:00     0.052020    0.061212     0.051631    0.061471
# 2015-12-28 14:00:00     0.052530    0.060995     0.052680    0.060874
# 2015-12-29 02:00:00     0.052829    0.060686     0.052206    0.061038
#
# [707 rows x 276 columns]

# %%
707 *0.75
# Out:
# 530.25

# %%
train_data = data.iloc[0:530]
test_data = data.iloc[530:]

train_data.shape, test_data.shape
# Out:
# ((530, 276), (177, 276))

# %%
lead_cols
# Out:
# ['label_lead_1',
#  'label_lead_2',
#  'label_lead_3',
#  'label_lead_4',
#  'label_lead_5',
#  'label_lead_6',
#  'label_lead_7',
#  'label_lead_8',
#  'label_lead_9',
#  'label_lead_10',
#  'label_lead_11']

# %%
lead_cols.insert(0, "label_lead_0") 
lead_cols
# Out:
# ['label_lead_0',
#  'label_lead_1',
#  'label_lead_2',
#  'label_lead_3',
#  'label_lead_4',
#  'label_lead_5',
#  'label_lead_6',
#  'label_lead_7',
#  'label_lead_8',
#  'label_lead_9',
#  'label_lead_10',
#  'label_lead_11']

# %%
x_train_data = train_data.drop(lead_cols, axis=1)
y_train_data = train_data.loc[:, lead_cols]
x_test_data = test_data.drop(lead_cols, axis=1)
y_test_data = test_data.loc[:, lead_cols]

# %%
y_train_data
# Out:
#                      label_lead_0  label_lead_1  label_lead_2  label_lead_3  \
# time
# 2015-01-10 02:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-10 14:00:00      0.589809      0.440792      0.238338      0.097323
# 2015-01-11 02:00:00      0.000000      0.000000      0.001804      0.000588
# 2015-01-11 14:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-12 02:00:00      0.004974      0.015529      0.021843      0.038199
# ...                           ...           ...           ...           ...
# 2015-09-29 14:00:00      0.372914      0.421254      0.458821      0.499441
# 2015-09-30 02:00:00      0.007230      0.000392      0.000000      0.032995
# 2015-09-30 14:00:00      0.267007      0.356133      0.330306      0.341235
# 2015-10-01 02:00:00      0.000000      0.000000      0.000000      0.004825
# 2015-10-01 14:00:00      0.270179      0.333500      0.288014      0.296454
#
#                      label_lead_4  label_lead_5  label_lead_6  label_lead_7  \
# time
# 2015-01-10 02:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-10 14:00:00      0.174303      0.141773      0.022883      0.013497
# 2015-01-11 02:00:00      0.000000      0.000000      0.000588      0.006535
# 2015-01-11 14:00:00      0.000000      0.000000      0.000000      0.000000
# 2015-01-12 02:00:00      0.083686      0.075961      0.111760      0.495158
# ...                           ...           ...           ...           ...
# 2015-09-29 14:00:00      0.323518      0.262002      0.242507      0.083739
# 2015-09-30 02:00:00      0.007059      0.000000      0.059814      0.603113
# 2015-09-30 14:00:00      0.338754      0.271536      0.053768      0.042394
# 2015-10-01 02:00:00      0.127832      0.126080      0.004784      0.356238
# 2015-10-01 14:00:00      0.101295      0.071392      0.134559      0.117662
#
#                      label_lead_8  label_lead_9  label_lead_10  label_lead_11
# time
# 2015-01-10 02:00:00      0.000000      0.023604       0.458870       0.519696
# 2015-01-10 14:00:00      0.003707      0.007590       0.001686       0.004118
# 2015-01-11 02:00:00      0.000000      0.000000       0.000000       0.000000
# 2015-01-11 14:00:00      0.000355      0.000353       0.001412       0.001412
# 2015-01-12 02:00:00      0.483788      0.471921       0.517523       0.503468
# ...                           ...           ...            ...            ...
# 2015-09-29 14:00:00      0.011940      0.005584       0.007230       0.007230
# 2015-09-30 02:00:00      0.573188      0.428225       0.372558       0.261057
# 2015-09-30 14:00:00      0.000178      0.000000       0.000000       0.000000
# 2015-10-01 02:00:00      0.215649      0.171182       0.216310       0.312184
# 2015-10-01 14:00:00      0.154251      0.000099       0.000099       0.000099
#
# [530 rows x 12 columns]

# %%
import lightgbm as lgbm
from sklearn import metrics
from sklearn import model_selection

# %%
threshold = 0
features = []
for col in y_train_data.columns:
    correlation = pd.DataFrame(train_data.drop(lead_cols, axis=1).corrwith(train_data[col]), columns=['corr'])
    thresh_corr = correlation[correlation['corr']> threshold]
    features.append(list(thresh_corr.index))

# %%
pd.DataFrame(features)
# Out:
#             0            1            2            3            4    \
# 0   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 1   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 2   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 3   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 4   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 5   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 6   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 7   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 8   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 9   label_lag_1  label_lag_2  label_lag_3  label_lag_4  label_lag_5
# 10  label_lag_4  label_lag_5  label_lag_6  label_lag_7  label_lag_8
# 11  label_lag_4  label_lag_5  label_lag_6  label_lag_7  label_lag_8
#
#              5             6             7             8             9    ...  \
# 0   label_lag_16  label_lag_17  label_lag_18  label_lag_19  label_lag_20  ...
# 1   label_lag_17  label_lag_18  label_lag_19  label_lag_20  label_lag_21  ...
# 2   label_lag_17  label_lag_18  label_lag_19  label_lag_20  label_lag_21  ...
# 3   label_lag_17  label_lag_18  label_lag_19  label_lag_20  label_lag_21  ...
# 4   label_lag_16  label_lag_17  label_lag_18  label_lag_19  label_lag_20  ...
# 5   label_lag_16  label_lag_17  label_lag_18  label_lag_19  label_lag_20  ...
# 6   label_lag_16  label_lag_17  label_lag_18  label_lag_19  label_lag_20  ...
# 7    label_lag_6   label_lag_7   label_lag_8   label_lag_9  label_lag_10  ...
# 8    label_lag_6   label_lag_7   label_lag_8   label_lag_9  label_lag_10  ...
# 9    label_lag_6   label_lag_7   label_lag_8   label_lag_9  label_lag_10  ...
# 10   label_lag_9  label_lag_10  label_lag_11  label_lag_12  label_lag_13  ...
# 11   label_lag_9  label_lag_10  label_lag_11  label_lag_12  label_lag_13  ...
#
#             254         255          256         257          258         259  \
# 0          None        None         None        None         None        None
# 1          None        None         None        None         None        None
# 2          None        None         None        None         None        None
# 3          None        None         None        None         None        None
# 4          None        None         None        None         None        None
# 5          None        None         None        None         None        None
# 6          None        None         None        None         None        None
# 7   rmean_20_60  rstd_20_60  rmean_21_60  rstd_21_60  rmean_22_60  rstd_22_60
# 8   rmean_20_60  rstd_20_60  rmean_21_60  rstd_21_60  rmean_22_60  rstd_22_60
# 9    rstd_24_60        None         None        None         None        None
# 10         None        None         None        None         None        None
# 11         None        None         None        None         None        None
#
#             260         261          262         263
# 0          None        None         None        None
# 1          None        None         None        None
# 2          None        None         None        None
# 3          None        None         None        None
# 4          None        None         None        None
# 5          None        None         None        None
# 6          None        None         None        None
# 7   rmean_23_60  rstd_23_60  rmean_24_60  rstd_24_60
# 8   rmean_23_60  rstd_23_60  rmean_24_60  rstd_24_60
# 9          None        None         None        None
# 10         None        None         None        None
# 11         None        None         None        None
#
# [12 rows x 264 columns]

# %%
result = pd.DataFrame()
models = dict()
for counter, col in enumerate(y_train_data.columns):
    
    result[f'pred_{counter}'] = np.zeros(y_test_data.shape[0])
    
    used_features = features[counter]
    
    x_train_local = x_train_data.loc[:, used_features]
    y_train_local = y_train_data.loc[:, col]
    x_test_local = x_test_data.loc[:, used_features]
    y_test_local = y_test_data.loc[:, col]
    
    
    model = lgbm.LGBMRegressor(
        objective='regression',
        max_depth=5,
        num_leaves=5 ** 2 - 1,
        learning_rate=0.007,
        n_estimators=30000,
        min_child_samples=80,
        subsample=0.8,
        colsample_bytree=1,
        reg_alpha=0,
        reg_lambda=0,
        random_state=np.random.randint(10e6)
    )

    n_splits = 6
    cv = model_selection.KFold(n_splits=n_splits, shuffle=True, random_state=42)

    val_scores = [0] * n_splits




    #feature_importances = pd.DataFrame(index=x_train_local.columns)

    for i, (fit_idx, val_idx) in enumerate(cv.split(x_train_local, y_train_local)):

        X_fit = x_train_local.iloc[fit_idx]
        y_fit = y_train_local.iloc[fit_idx]
        X_val = x_train_local.iloc[val_idx]
        y_val = y_train_local.iloc[val_idx]

        model.fit(
            X_fit,
            y_fit,
            eval_set=[(X_fit, y_fit), (X_val, y_val)],
            eval_names=('fit', 'val'),
            eval_metric='l2',
            early_stopping_rounds=200,
            feature_name=X_fit.columns.tolist(),
            verbose=False
        )

        val_scores[i] = np.sqrt(model.best_score_['val']['l2'])
        result[f'pred_{counter}'] += model.predict(x_test_local, num_iteration=model.best_iteration_)
        #feature_importances[i] = model.feature_importances_

        print('Fold {} RMSLE: {:.5f}'.format(i+1, val_scores[i]))

    result[f'pred_{counter}'] /= n_splits
    result[f'pred_{counter}'] = np.expm1(result[f'pred_{counter}'])

    val_mean = np.mean(val_scores)
    val_std = np.std(val_scores)

    print('Local RMSLE: {:.5f} (±{:.5f})'.format(val_mean, val_std))
    models[col] = model
# Out:
# Fold 1 RMSLE: 0.05977
# Fold 2 RMSLE: 0.08738
# Fold 3 RMSLE: 0.10570
# Fold 4 RMSLE: 0.08472
# Fold 5 RMSLE: 0.08640
# Fold 6 RMSLE: 0.10225
# Local RMSLE: 0.08771 (±0.01487)
# Fold 1 RMSLE: 0.07953
# Fold 2 RMSLE: 0.09267
# Fold 3 RMSLE: 0.10305
# Fold 4 RMSLE: 0.10085
# Fold 5 RMSLE: 0.09959
# Fold 6 RMSLE: 0.09097
# Local RMSLE: 0.09444 (±0.00795)
# Fold 1 RMSLE: 0.09270
# Fold 2 RMSLE: 0.09166
# Fold 3 RMSLE: 0.10651
# Fold 4 RMSLE: 0.11632
# Fold 5 RMSLE: 0.11133
# Fold 6 RMSLE: 0.10049
# Local RMSLE: 0.10317 (±0.00913)
# Fold 1 RMSLE: 0.10331
# Fold 2 RMSLE: 0.09296
# Fold 3 RMSLE: 0.13541
# Fold 4 RMSLE: 0.11046
# Fold 5 RMSLE: 0.11463
# Fold 6 RMSLE: 0.11605
# Local RMSLE: 0.11214 (±0.01299)
# Fold 1 RMSLE: 0.09904
# Fold 2 RMSLE: 0.09670
# Fold 3 RMSLE: 0.13957
# Fold 4 RMSLE: 0.10569
# Fold 5 RMSLE: 0.10578
# Fold 6 RMSLE: 0.12148
# Local RMSLE: 0.11138 (±0.01488)
# Fold 1 RMSLE: 0.10931
# Fold 2 RMSLE: 0.10530
# Fold 3 RMSLE: 0.13521
# Fold 4 RMSLE: 0.10371
# Fold 5 RMSLE: 0.10184
# Fold 6 RMSLE: 0.13132
# Local RMSLE: 0.11445 (±0.01354)
# Fold 1 RMSLE: 0.10673
# Fold 2 RMSLE: 0.11876
# Fold 3 RMSLE: 0.13483
# Fold 4 RMSLE: 0.10592
# Fold 5 RMSLE: 0.10949
# Fold 6 RMSLE: 0.11985
# Local RMSLE: 0.11593 (±0.01006)
# Fold 1 RMSLE: 0.12172
# Fold 2 RMSLE: 0.13849
# Fold 3 RMSLE: 0.15342
# Fold 4 RMSLE: 0.11997
# Fold 5 RMSLE: 0.14726
# Fold 6 RMSLE: 0.13882
# Local RMSLE: 0.13661 (±0.01227)
# Fold 1 RMSLE: 0.15836
# Fold 2 RMSLE: 0.13498
# Fold 3 RMSLE: 0.16534
# Fold 4 RMSLE: 0.15946
# Fold 5 RMSLE: 0.18691
# Fold 6 RMSLE: 0.15943
# Local RMSLE: 0.16075 (±0.01516)
# Fold 1 RMSLE: 0.15317
# Fold 2 RMSLE: 0.13455
# Fold 3 RMSLE: 0.16833
# Fold 4 RMSLE: 0.16586
# Fold 5 RMSLE: 0.17693
# Fold 6 RMSLE: 0.15218
# Local RMSLE: 0.15850 (±0.01374)
# Fold 1 RMSLE: 0.15292
# Fold 2 RMSLE: 0.11648
# Fold 3 RMSLE: 0.16352
# Fold 4 RMSLE: 0.14757
# Fold 5 RMSLE: 0.15895
# Fold 6 RMSLE: 0.15880
# Local RMSLE: 0.14971 (±0.01570)
# Fold 1 RMSLE: 0.14899
# Fold 2 RMSLE: 0.11501
# Fold 3 RMSLE: 0.16487
# Fold 4 RMSLE: 0.13003
# Fold 5 RMSLE: 0.17080
# Fold 6 RMSLE: 0.15450
# Local RMSLE: 0.14737 (±0.01939)

# %%
result
# Out:
#        pred_0    pred_1    pred_2    pred_3    pred_4    pred_5    pred_6  \
# 0   -0.030076 -0.017161  0.000261 -0.010441 -0.000563  0.032828  0.055082
# 1    0.559208  0.621743  0.568061  0.441323  0.422762  0.404373  0.270622
# 2    0.378883  0.264089  0.259713  0.268706  0.216109  0.191220  0.170243
# 3    0.087006  0.091437  0.104917  0.142029  0.156723  0.153837  0.149503
# 4    0.014542  0.048614  0.028565  0.026984  0.013089  0.031750  0.042479
# ..        ...       ...       ...       ...       ...       ...       ...
# 172  0.209731  0.156124  0.168967  0.112666  0.091730  0.076515  0.052425
# 173  0.012501 -0.008658  0.004623  0.004580  0.016855  0.044238  0.058244
# 174  0.060527  0.081043  0.064843  0.066926  0.065295  0.036178  0.041622
# 175 -0.010115 -0.000594 -0.001714  0.011312  0.009882  0.004656  0.016905
# 176  0.067653  0.086471  0.063962  0.071132  0.073010  0.033679  0.036591
#
#        pred_7    pred_8    pred_9   pred_10   pred_11
# 0    0.084982  0.148748  0.186823  0.176439  0.105134
# 1    0.197110  0.089889  0.025528  0.024323  0.011081
# 2    0.222782  0.235051  0.287432  0.324151  0.290656
# 3    0.172703  0.272390  0.253523  0.186849  0.177591
# 4    0.057340  0.066961  0.066669  0.062506  0.052397
# ..        ...       ...       ...       ...       ...
# 172  0.113481  0.157789  0.149800  0.138296  0.126587
# 173  0.040166  0.142559  0.151658  0.149225  0.104503
# 174  0.093046  0.082699  0.073917  0.080931  0.097926
# 175  0.053858  0.077163  0.074645  0.089695  0.082232
# 176  0.084176  0.105380  0.108046  0.121876  0.120594
#
# [177 rows x 12 columns]

# %%
final_test = y_test_data.values.flatten()
final_resut = result.values.flatten()

# %%
plt.figure(figsize=(18,5))

plt.plot(final_test[330:500], marker='.',label='Target')
plt.plot(final_resut[330:500], marker='.', label='Predictions')
plt.title('Elec consumption')
plt.xlabel('Time(h)')
plt.ylabel('Elec consump (khw)')
plt.legend()
plt.show()

# %%
print( "The RMSE for Stacked LSTM model is: %f" %np.sqrt(mean_squared_error(final_test,final_resut)))
print( "The accuracy of Stacked LSTM model is: %f" %r2_score(final_test,final_resut))
# Out:
# The RMSE for Stacked LSTM model is: 0.153758
# The accuracy of Stacked LSTM model is: 0.438964

# %%
final_test_reverse = np.array(final_test[0:len(final_test)-1])
final_resut_reverse= np.array(final_resut[1:])

# %%
print( "The RMSE for Stacked LSTM model is: %f" %np.sqrt(mean_squared_error(final_test_reverse,final_resut_reverse)))
print( "The accuracy of Stacked LSTM model is: %f" %r2_score(final_test_reverse,final_resut_reverse))
# Out:
# The RMSE for Stacked LSTM model is: 0.148217
# The accuracy of Stacked LSTM model is: 0.478806
